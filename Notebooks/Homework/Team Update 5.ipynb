# %% [markdown]
# # Team Update 5
#
# For this assignment, you'll be creating a complete version of your design system from start to finish. Modify the code cells below to reflect your design choices.

# %%
import os
from pathlib import Path

import sys
ISST_DIR = str(Path(os.getcwd()).parent.parent.parent)
sys.path.append(ISST_DIR)

import numpy as np
import arviz as az
import pymc as pm

import ISST
# Out:
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %% [markdown]
# # Cost Risk Table
#
# First, create your overall cost Risk Table by completing the inputs for the Risk Table. Adjust your breakpoints and utility levels to obtain a satisfactory utility function.

# %%
Cost_Risk_Table = ISST.RiskTable(name='LogCost',
                                 units = 'logEUR',
                                 utility_breakpoints=np.log10([0.5*1e5, 1*1e6, 4*1e6, 10*1e6, 30*1e6, 50*1e6]),
                                 utilities=[-1., -2., -4., -6., -8., -10.],
                                 utility_names=['50k Euros',
                                                '1M Euros',
                                                '4M Euros',
                                                '10M Euros',
                                                '30M Euros',
                                                '50M Euros']
                                 )

Cost_Risk_Table.plot_utilities()

# %%
np.log10([0.5*1e5, 2.5*1e6, 15*1e6, 25*1e6, 35*1e6, 50*1e6])
# Out:
# array([4.69897   , 6.39794001, 7.17609126, 7.39794001, 7.54406804,
#        7.69897   ])

# %% [markdown]
# # Schedule Risk Table
#
# Next, the same for your schedule risk table:

# %%
Schedule_Risk_Table = ISST.RiskTable(name='Schedule',
                                     units = 'months',
                                     utility_breakpoints=[0., 1., 3., 6., 12., 18., 24.],
                                     utilities=[0., -1., -2., -4., -6., -8., -10.],
                                     utility_names=['0 Months',
                                                '1 Month',
                                                '3 Months',
                                                '6 Months',
                                                '12 Months',
                                                '18 Months',
                                                '24 Months']
                                     )

Schedule_Risk_Table.plot_utilities()

# %% [markdown]
# # Technical Risk Tables
#
# Next, your Technical Risk Tables. Identify the key technical parameters for each sub team, and assemble risk tables for each. There should be at minimum one risk table per sub-team, but not more than three. Copy and paste the code below as necessary, changing the variable names and the `name` parameter of the Risk Table.

# %% [markdown]
# ### Performance (Sensors, Communications, Data)

# %%
GRS_Resolution = ISST.RiskTable(name='GRS',
                               units = '',
                               utility_breakpoints=[],
                               utilities=[],
                               utility_names=[]
                               )

GRS_Resolution.plot_utilities()

# %%
Radiation_Sensor = ISST.RiskTable(name='Raditaion',
                               units = '',
                               utility_breakpoints=[],
                               utilities=[],
                               utility_names=[]
                               )

Radiation_Sensor.plot_utilities()

# %%
Contextual_Data = ISST.RiskTable(name='Context',
                               units = '',
                               utility_breakpoints=[],
                               utilities=[],
                               utility_names=[]
                               )

Contextual_Data.plot_utilities()

# %% [markdown]
# ### Platform (Structure, Thermal, Electrical)

# %%
Payload_Power = ISST.RiskTable(name='Power',
                               units = 'W',
                               utility_breakpoints=[],
                               utilities=[],
                               utility_names=[]
                               )

Payload_Power.plot_utilities()

# %%
Payload_Heat_Margin = ISST.RiskTable(name='HeatRejection',
                               units = 'W',
                               utility_breakpoints=[],
                               utilities=[],
                               utility_names=[]
                               )

Payload_Heat_Margin.plot_utilities()

# %% [markdown]
# ### Propulsion

# %%
Payload_Delta_v = ISST.RiskTable(name='DeltaV',
                               units = 'm/s',
                               utility_breakpoints=[],
                               utilities=[],
                               utility_names=[]
                               )

Payload_Delta_v.plot_utilities()

# %%
Payload_ADCS_Impulse = ISST.RiskTable(name='Impulse',
                               units = 'kg m/s',
                               utility_breakpoints=[],
                               utilities=[],
                               utility_names=[]
                               )

Payload_ADCS_Impulse.plot_utilities()

# %%
Payload_Mass = ISST.RiskTable(name='Mass',
                               units = 'kg',
                               utility_breakpoints=[],
                               utilities=[],
                               utility_names=[]
                               )

Payload_Mass.plot_utilities()

# %% [markdown]
# # Risks
#
# Identify the most important risks to your cost, schedule, and each technical parameter of your design system. You should have at minimum one major risk for each risk table identified above, and no more than three times as many risks as risk tables.

# %%
# Cost Risks
Funding_Risk = ISST.Risk(name='Costs Need to be Spread Out', baseline_likelihood = 0.00)
Production_Risk = ISST.Risk(name='Industrial Base is Unavailable', baseline_likelihood = 0.00)
#Schedule Risks
Qual_Risk = ISST.Risk(name='Components Fail During Qualification', baseline_likelihood = 0.00)
Leak_Risk = ISST.Risk(name='Propellant Leak During Assembly', baseline_likelihood = 0.00)
#GRS Resolution
Exhasut_Risk = ISST.Risk(name='Thruster Exhaust Interferes with Sensors', baseline_likelihood = 0.00)
#Radiation Data
Calibration_Risk = ISST.Risk(name='Sensor Calibration Fails', baseline_likelihood = 0.00)
#Contextual Data
Light_Risk = ISST.Risk(name='Sensors are Damaged by the Sun', baseline_likelihood = 0.00)
#Payload Power
Aging_Risk = ISST.Risk(name='Elecctrical Degredation is Accelerated', baseline_likelihood = 0.00)
#Payload Heat Margin
Deployable_Risk = ISST.Risk(name='Mecahnisms Fail to Deploy', baseline_likelihood = 0.00)
#Payload Mass
Manufacturing_Risk = ISST.Risk(name='Assembly Requires Design Modifications', baseline_likelihood = 0.00)
#Payload Delta v
Dev_Risk = ISST.Risk(name='Technological Maturity is Behind Expectations', baseline_likelihood = 0.00)
#Payload ADCS Impulse
Instability_Risk = ISST.Risk(name='Orbit Stability is Below Expectations', baseline_likelihood = 0.00)

# %% [markdown]
# # Design System
#
# Specify your design system

# %%
full_risk_list = [Funding_Risk, Production_Risk, Qual_Risk, Leak_Risk, Exhaust_Risk, Calibration_Risk, Light_Risk, Aging_Risk, Deployable_Risk, Manufacturing_Risk, Dev_Risk, Instability_Risk]
full_technical_risk_list = [GRS_Resolution, Radiation_Sensor, Contextual_Data, Payload_Power, Payload_Heat_Margin, Payload_Delta_v, Payload_ADCS_Impulse, Payload_Mass]

# %%
Design_System = ISST.DesignSystem(name='First_Design_System',
                                  model_context=pm.Model(),
                                  risks = full_risk_list,
                                  schedule_risk_table = Schedule_Risk_Table,
                                  cost_risk_table = Cost_Risk_Table,
                                  technical_risk_tables = full_technical_risk_list)

# %% [markdown]
# # Risk Specification
#
# Run the `generate_system_specification` method for your design system

# %%
Design_System.generate_system_specification()

# %% [markdown]
# You will now have CSV files in a subdirectory which can be used to fill out your risk specification.
#
# Once they are filled out, read the specification back into your design system.

# %%
Design_System.read_system_specification()

# %% [markdown]
# # Analyze System
#
# Run the Monte Carlo simulation of your design system and save them to a file.

# %%
results = Design_System.analyze_system()
results.to_netcdf('Analysis Results.nc')

# %% [markdown]
# # Results Inspection

# %% [markdown]
# First, let's look at the summary of results for your total impacts:

# %%
az.plot_posterior(results,
                  var_names=['Total'],
                  filter_vars='like',
                  hdi_prob=0.95)

# %%
az.summary(results,
           var_names=['Total'],
           filter_vars="like",
           round_to=2,
           kind='stats')

# %% [markdown]
# Next, the results for your cost analysis:

# %%
az.plot_posterior(results,
                  var_names=['Cost'],
                  filter_vars='like',
                  hdi_prob=0.95)

# %%
az.summary(results,
           var_names=['Cost'],
           filter_vars="like",
           round_to=2,
           kind='stats')

# %% [markdown]
# Next, the results for your schedule analysis:

# %%
az.plot_posterior(results,
                  var_names=['Schedule'],
                  filter_vars='like',
                  hdi_prob=0.95)

# %%
az.summary(results,
           var_names=['Schedule'],
           filter_vars="like",
           round_to=2,
           kind='stats')

# %% [markdown]
# And finally, for your technical parameters:

# %%
for idx, risk in Design_System.risks:
    print(f'Technical Parameter {idx}: {risk.name}')

# %%
az.plot_posterior(results,
                  var_names=['Technical'],
                  filter_vars='like',
                  hdi_prob=0.95)

# %%
az.summary(results,
           var_names=['Schedule'],
           filter_vars="like",
           round_to=2,
           kind='stats')

# %% [markdown]
# # Assignment Submission
#
# Once your results are in place for all of the above elements, print the notebook to PDF and submit it to the assignment.
